# %%
import sqlite3

# %%
# Connect to the database file
conn = sqlite3.connect('/content/drive/MyDrive/ML_assignment1/database.sqlite')

# %%
cursor = conn.cursor()

# %%
# checking for the tables present in the database file
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")

# %%
rows = cursor.fetchall()

# %%
for i in rows:
  print(i[0])
# Out:
# sqlite_sequence
# Player_Attributes
# Player
# Match
# League
# Country
# Team
# Team_Attributes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # complete dataset

# %%
import pandas as pd
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type = 'table';""",conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# ...

# %% [markdown]
# # let's go to each of the file and try to look into the individual tables

# %%
for table in rows:
  data = pd.read_sql(f"""SELECT *
                        FROM {table[0]};""", conn)
  print(f'_______________________{table[0]}_________________')
  data.to_csv(f'/content/drive/MyDrive/ML_assignment1/Datasets/{table[0]}.csv', index = False)
  print(f'{table[0]} file has been saved')
# Out:
# _______________________sqlite_sequence_________________
# sqlite_sequence file has been saved
# _______________________Player_Attributes_________________
# Player_Attributes file has been saved
# _______________________Player_________________
# Player file has been saved
# _______________________Match_________________
# Match file has been saved
# _______________________League_________________
# League file has been saved
# _______________________Country_________________
# Country file has been saved
# _______________________Team_________________
# Team file has been saved
# _______________________Team_Attributes_________________
# Team_Attributes file has been saved

# %% [markdown]
# Team performance: We can analyze the performance of different teams over time, including their win/loss record, goals scored, goals conceded, and goal differential.
#
# Player performance: We can analyze the performance of individual players, including their goals scored, assists, shots, and overall rating.
#
# League comparison: We can compare the performance of different leagues, including the average number of goals per match, the number of draws, and the number of high-scoring matches.
#
# Tactical analysis: We can study the impact of different tactical approaches on the outcome of matches, such as the number of shots taken, the number of fouls committed, and the number of corners won.
#
# Player positions: We can analyze the performance of different player positions, including forwards, midfielders, defenders, and goalkeepers.
#
# Home field advantage: We can study the impact of playing at home versus playing away, including the number of wins, losses, and draws for each team.
#
# Seasonal trends: We can analyze seasonal trends in the performance of teams and players, such as the number of goals scored in the first half versus the second half, or the number of wins and losses in the first half versus the second half of the season.
